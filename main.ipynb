# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
def lines(slope=0.5, offset=0.2, start=0,stop=10,step=0.1):
    X = np.array([[x,x*slope-offset] for x in np.arange(start,stop,step)] + [[x,x*slope+offset] for x in np.arange(start,stop,step)])
    y = np.array([1 for i in np.arange(start,stop,step)] + [0 for i in np.arange(start,stop,step)])
    return X,y


# Pandas is used for data manipulation
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.decomposition import PCA
from sklearn import model_selection

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import precision_score, recall_score

def train_report(clf,X,y):
    clf.fit(X, y)
    print("accuracy:",clf.score(X,y)) # classification accuracy

    # Plot the decision boundary
    plot_decision_boundary(lambda x: clf.predict(x),X,y)
    plt.show()

# %%
def plot_decision_boundary(pred_func, X,y):
    # Set min and max values and give it some padding
    x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
    y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
    h = 0.01
    # Generate a grid of points with distance h between them
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    # Predict the function value for the whole gid
    Z = pred_func(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    # Plot the contour and training examples
    plt.contourf(xx, yy, Z, cmap=plt.cm.Spectral)
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Spectral)

# %%
# Read in data and display first 5 rows
features = pd.read_csv('ds2.csv')
features.head(5)


X = features.drop('calving difficulty', axis=1)
y = features['calving difficulty']

# %%
# list for column headers
print(features.shape)
# print head of data set
print(features.head())
# Out:
# (90, 7)
#    race  lactation  twins  sex  THI mean  THI variance  calving difficulty
# 0     0          2      0    0   63.3241       17.6722                   0
# 1     0          4      0    0   66.8641       17.2446                   0
# 2     1          0      0    0   63.3241       17.6722                   0
# 3     0          5      0    0   65.5977       36.0564                   3
# 4     0          2      0    1   65.1415       26.8230                   0

# %% [markdown]
# # PCA
# for plotting purpose, PCA is set to 2 for now
# We can check with different components to get more accurate model

# %%
pca = PCA(n_components=2)
NX = pca.fit_transform(X)


# implementing train-test-split
X_train, X_test, y_train, y_test = train_test_split(NX, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Random Forest

# %%
# random forest model creation
rfc = RandomForestClassifier()
#from sklearn.svm import SVC
#svclassifier = SVC(kernel='linear')
train_report(rfc, X_train, y_train)
    # predictions
# Out:
# C:\Users\amirh\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# accuracy: 0.9206349206349206
# C:\Users\amirh\Anaconda3\lib\site-packages\numpy\ma\core.py:6461: MaskedArrayFutureWarning: In the future the default for ma.minimum.reduce will be axis=0, not the current None, to match np.minimum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)
# C:\Users\amirh\Anaconda3\lib\site-packages\numpy\ma\core.py:6461: MaskedArrayFutureWarning: In the future the default for ma.maximum.reduce will be axis=0, not the current None, to match np.maximum.reduce. Explicitly pass 0 or None to silence this warning.
#   return self.reduce(a)

# %%
y_pred = rfc.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[11  2  0  0]
#  [ 6  2  0  0]
#  [ 4  1  0  0]
#  [ 1  0  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.85      0.63        13
#            1       0.40      0.25      0.31         8
#            2       0.00      0.00      0.00         5
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.48        27
#    macro avg       0.23      0.27      0.23        27
# weighted avg       0.36      0.48      0.39        27
# C:\Users\amirh\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svclassifier = SVC(kernel='rbf')
train_report(svclassifier, X_train, y_train)
# Out:
# accuracy: 0.9206349206349206
# C:\Users\amirh\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-d65037ecdbbd> in <module>()
#       1 from sklearn.svm import SVC
#       2 svclassifier = SVC(kernel='rbf')
# ----> 3 train_report(svclassifier, X_train, y_train)
#
# <ipython-input-1-d433ae4678fa> in train_report(clf, X, y)
#      24
#      25     # Plot the decision boundary
# ---> 26     plot_decision_boundary(lambda x: clf.predict(x),X,y)
#      27     plt.show()
#
# <ipython-input-2-4cd31d056955> in plot_decision_boundary(pred_func, X, y)
#       1 def plot_decision_boundary(pred_func, X,y):
#       2     # Set min and max values and give it some padding
# ----> 3     x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
#       4     y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
#       5     h = 0.01
#
# C:\Users\amirh\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\Users\amirh\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key

# %%
y_pred = svclassifier.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[12  1  0  0]
#  [ 7  1  0  0]
#  [ 5  0  0  0]
#  [ 1  0  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.48      0.92      0.63        13
#            1       0.50      0.12      0.20         8
#            2       0.00      0.00      0.00         5
#            3       0.00      0.00      0.00         1
#
#     accuracy                           0.48        27
#    macro avg       0.24      0.26      0.21        27
# weighted avg       0.38      0.48      0.36        27
# C:\Users\amirh\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
svclassifier = SVC(kernel='linear')
train_report(svclassifier, X_train, y_train)
y_pred = svclassifier.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuracy: 0.6507936507936508
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-3683cdadfd19> in <module>()
#       1 svclassifier = SVC(kernel='linear')
# ----> 2 train_report(svclassifier, X_train, y_train)
#       3 y_pred = svclassifier.predict(X_test)
#       4
#       5 from sklearn.metrics import classification_report, confusion_matrix
#
# <ipython-input-1-d433ae4678fa> in train_report(clf, X, y)
#      24
#      25     # Plot the decision boundary
# ---> 26     plot_decision_boundary(lambda x: clf.predict(x),X,y)
#      27     plt.show()
#
# <ipython-input-2-4cd31d056955> in plot_decision_boundary(pred_func, X, y)
#       1 def plot_decision_boundary(pred_func, X,y):
#       2     # Set min and max values and give it some padding
# ----> 3     x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
#       4     y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
#       5     h = 0.01
#
# C:\Users\amirh\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\Users\amirh\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()
train_report(clf, X_train, y_train)
y_pred = clf.predict(X_test)

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# accuracy: 1.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-84d65dcf9ebc> in <module>()
#       2
#       3 clf = tree.DecisionTreeClassifier()
# ----> 4 train_report(clf, X_train, y_train)
#       5 y_pred = clf.predict(X_test)
#       6
#
# <ipython-input-1-d433ae4678fa> in train_report(clf, X, y)
#      24
#      25     # Plot the decision boundary
# ---> 26     plot_decision_boundary(lambda x: clf.predict(x),X,y)
#      27     plt.show()
#
# <ipython-input-2-4cd31d056955> in plot_decision_boundary(pred_func, X, y)
#       1 def plot_decision_boundary(pred_func, X,y):
#       2     # Set min and max values and give it some padding
# ----> 3     x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
#       4     y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
#       5     h = 0.01
#
# C:\Users\amirh\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\Users\amirh\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key

# %%
from IPython.display import Image

tree.export_graphviz(clf,out_file='dt.dot')

# !dot -Tpng dt.dot -o dt.png
Image("dt.png")

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

train_report(clf, X_train, y_train)
# Out:
# accuracy: 0.6031746031746031
# C:\Users\amirh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\amirh\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-7921cf8bb879> in <module>()
#       3 clf = LogisticRegression()
#       4
# ----> 5 train_report(clf, X_train, y_train)
#
# <ipython-input-1-d433ae4678fa> in train_report(clf, X, y)
#      24
#      25     # Plot the decision boundary
# ---> 26     plot_decision_boundary(lambda x: clf.predict(x),X,y)
#      27     plt.show()
#
# <ipython-input-2-4cd31d056955> in plot_decision_boundary(pred_func, X, y)
#       1 def plot_decision_boundary(pred_func, X,y):
#       2     # Set min and max values and give it some padding
# ----> 3     x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
#       4     y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5
#       5     h = 0.01
#
# C:\Users\amirh\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# C:\Users\amirh\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key

# %%
y_pred = clf.predict(X_test)

print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
